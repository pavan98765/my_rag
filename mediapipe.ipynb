# %%
# Out:
# Collecting mediapipe
#   Obtaining dependency information for mediapipe from https://files.pythonhosted.org/packages/ea/1b/79e1ddc041012f5e5a7d60cbfd8cfe6037c5c87f4e77b4fdc0f9dfa2d44e/mediapipe-0.10.14-cp310-cp310-win_amd64.whl.metadata
#   Downloading mediapipe-0.10.14-cp310-cp310-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: absl-py in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from mediapipe) (2.0.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from mediapipe) (22.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from mediapipe) (23.5.26)
# Requirement already satisfied: jax in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from mediapipe) (0.4.16)
# Collecting jaxlib (from mediapipe)
#   Obtaining dependency information for jaxlib from https://files.pythonhosted.org/packages/14/a6/dcea38d490672a45ce52d957a25f7716d1980dc5cf393aae90905f3b721f/jaxlib-0.4.29-cp310-cp310-win_amd64.whl.metadata
#   Downloading jaxlib-0.4.29-cp310-cp310-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: matplotlib in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from mediapipe) (3.8.0)
# Requirement already satisfied: numpy in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from mediapipe) (1.23.5)
# Requirement already satisfied: opencv-contrib-python in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from mediapipe) (4.8.1.78)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Obtaining dependency information for protobuf<5,>=4.25.3 from https://files.pythonhosted.org/packages/ad/6e/1bed3b7c904cc178cb8ee8dbaf72934964452b3de95b7a63412591edb93c/protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata
#   Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Obtaining dependency information for sounddevice>=0.4.4 from https://files.pythonhosted.org/packages/d4/09/bfdd393f1bb1b90b4a6849b84972b7059c95e36818cc489922228d58cc63/sounddevice-0.4.7-py3-none-win_amd64.whl.metadata
#   Downloading sounddevice-0.4.7-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: CFFI>=1.0 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.15.1)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from jax->mediapipe) (0.3.0)
# Requirement already satisfied: opt-einsum in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from jax->mediapipe) (1.11.2)
# Collecting ml-dtypes>=0.2.0 (from jax->mediapipe)
#   Obtaining dependency information for ml-dtypes>=0.2.0 from https://files.pythonhosted.org/packages/ea/31/cc9b87fbbb3f4bf2cb1a4aeb7648bd6d6c558dc3f60e1bd21958f18ddf71/ml_dtypes-0.4.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading ml_dtypes-0.4.0-cp310-cp310-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from matplotlib->mediapipe) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jarvis\appdata\roaming\python\python310\site-packages (from matplotlib->mediapipe) (0.10.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from matplotlib->mediapipe) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from matplotlib->mediapipe) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from matplotlib->mediapipe) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: pycparser in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: six in c:\users\jarvis\anaconda3\envs\detect\lib\site-packages (from cycler>=0.10->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.14-cp310-cp310-win_amd64.whl (50.8 MB)
#    ---------------------------------------- 0.0/50.8 MB ? eta -:--:--
#    ---------------------------------------- 0.2/50.8 MB 5.9 MB/s eta 0:00:09
#     --------------------------------------- 1.1/50.8 MB 17.5 MB/s eta 0:00:03
#    -- ------------------------------------- 2.7/50.8 MB 21.3 MB/s eta 0:00:03
#    --- ------------------------------------ 3.9/50.8 MB 24.9 MB/s eta 0:00:02
#    --- ------------------------------------ 4.1/50.8 MB 20.3 MB/s eta 0:00:03
#    ---- ----------------------------------- 6.3/50.8 MB 26.7 MB/s eta 0:00:02
#    ------ --------------------------------- 7.8/50.8 MB 27.7 MB/s eta 0:00:02
#    ------- -------------------------------- 9.2/50.8 MB 27.9 MB/s eta 0:00:02
#    -------- ------------------------------- 10.4/50.8 MB 29.7 MB/s eta 0:00:02
#    --------- ------------------------------ 11.8/50.8 MB 31.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 13.0/50.8 MB 29.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 14.2/50.8 MB 34.4 MB/s eta 0:00:02
#    ------------ --------------------------- 15.3/50.8 MB 29.8 MB/s eta 0:00:02
#    ------------- -------------------------- 16.6/50.8 MB 29.8 MB/s eta 0:00:02
#    -------------- ------------------------- 17.8/50.8 MB 29.7 MB/s eta 0:00:02
#    -------------- ------------------------- 19.0/50.8 MB 28.5 MB/s eta 0:00:02
#    --------------- ------------------------ 20.2/50.8 MB 28.5 MB/s eta 0:00:02
#    ---------------- ----------------------- 21.4/50.8 MB 29.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 22.8/50.8 MB 28.5 MB/s eta 0:00:01
#    ------------------ --------------------- 24.0/50.8 MB 29.8 MB/s eta 0:00:01
#    ------------------- -------------------- 25.2/50.8 MB 28.5 MB/s eta 0:00:01
#    -------------------- ------------------- 26.5/50.8 MB 28.5 MB/s eta 0:00:01
#    --------------------- ------------------ 27.8/50.8 MB 28.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 28.9/50.8 MB 27.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 30.2/50.8 MB 27.3 MB/s eta 0:00:01
#    ------------------------ --------------- 31.5/50.8 MB 27.3 MB/s eta 0:00:01
#    ------------------------- -------------- 32.9/50.8 MB 28.4 MB/s eta 0:00:01
#    -------------------------- ------------- 33.8/50.8 MB 27.3 MB/s eta 0:00:01
#    --------------------------- ------------ 34.4/50.8 MB 26.2 MB/s eta 0:00:01
#    --------------------------- ------------ 35.0/50.8 MB 25.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 36.1/50.8 MB 24.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 37.4/50.8 MB 24.2 MB/s eta 0:00:01
#    ------------------------------ --------- 38.5/50.8 MB 25.2 MB/s eta 0:00:01
#    ------------------------------- -------- 39.5/50.8 MB 25.1 MB/s eta 0:00:01
#    -------------------------------- ------- 40.8/50.8 MB 25.2 MB/s eta 0:00:01
#    --------------------------------- ------ 42.1/50.8 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.3/50.8 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 44.6/50.8 MB 26.2 MB/s eta 0:00:01
#    ------------------------------------ --- 45.8/50.8 MB 29.7 MB/s eta 0:00:01
#    ------------------------------------- -- 47.2/50.8 MB 29.7 MB/s eta 0:00:01
#    -------------------------------------- - 48.6/50.8 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  49.8/50.8 MB 29.8 MB/s eta 0:00:01
#    ---------------------------------------  50.8/50.8 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  50.8/50.8 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 50.8/50.8 MB 22.6 MB/s eta 0:00:00
# Downloading protobuf-4.25.3-cp310-abi3-win_amd64.whl (413 kB)
#    ---------------------------------------- 0.0/413.4 kB ? eta -:--:--
#    ---------------------------------------- 413.4/413.4 kB ? eta 0:00:00
# Downloading sounddevice-0.4.7-py3-none-win_amd64.whl (200 kB)
#    ---------------------------------------- 0.0/200.1 kB ? eta -:--:--
#    ---------------------------------------- 200.1/200.1 kB ? eta 0:00:00
# Downloading jaxlib-0.4.29-cp310-cp310-win_amd64.whl (51.5 MB)
#    ---------------------------------------- 0.0/51.5 MB ? eta -:--:--
#    - -------------------------------------- 1.3/51.5 MB 42.9 MB/s eta 0:00:02
#    -- ------------------------------------- 2.9/51.5 MB 36.5 MB/s eta 0:00:02
#    --- ------------------------------------ 4.0/51.5 MB 31.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 5.2/51.5 MB 29.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 6.1/51.5 MB 29.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 7.2/51.5 MB 28.8 MB/s eta 0:00:02
#    ------ --------------------------------- 8.5/51.5 MB 28.5 MB/s eta 0:00:02
#    ------- -------------------------------- 9.9/51.5 MB 30.2 MB/s eta 0:00:02
#    -------- ------------------------------- 10.9/51.5 MB 28.4 MB/s eta 0:00:02
#    --------- ------------------------------ 11.9/51.5 MB 28.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 13.3/51.5 MB 28.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 14.6/51.5 MB 28.4 MB/s eta 0:00:02
#    ------------ --------------------------- 16.0/51.5 MB 28.4 MB/s eta 0:00:02
#    ------------- -------------------------- 17.0/51.5 MB 29.7 MB/s eta 0:00:02
#    -------------- ------------------------- 18.3/51.5 MB 29.7 MB/s eta 0:00:02
#    --------------- ------------------------ 19.8/51.5 MB 29.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 20.9/51.5 MB 28.5 MB/s eta 0:00:02
#    ----------------- ---------------------- 22.4/51.5 MB 29.8 MB/s eta 0:00:01
#    ------------------ --------------------- 23.6/51.5 MB 28.5 MB/s eta 0:00:01
#    ------------------- -------------------- 24.9/51.5 MB 28.5 MB/s eta 0:00:01
#    -------------------- ------------------- 26.0/51.5 MB 28.5 MB/s eta 0:00:01
#    --------------------- ------------------ 27.3/51.5 MB 29.7 MB/s eta 0:00:01
#    --------------------- ------------------ 28.2/51.5 MB 28.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 29.5/51.5 MB 28.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 30.5/51.5 MB 27.3 MB/s eta 0:00:01
#    ------------------------ --------------- 31.7/51.5 MB 27.3 MB/s eta 0:00:01
#    ------------------------- -------------- 33.0/51.5 MB 28.5 MB/s eta 0:00:01
#    -------------------------- ------------- 34.3/51.5 MB 28.5 MB/s eta 0:00:01
#    --------------------------- ------------ 35.5/51.5 MB 29.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 36.9/51.5 MB 29.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 38.2/51.5 MB 28.5 MB/s eta 0:00:01
#    ------------------------------ --------- 39.0/51.5 MB 28.5 MB/s eta 0:00:01
#    ------------------------------- -------- 40.3/51.5 MB 28.5 MB/s eta 0:00:01
#    -------------------------------- ------- 41.4/51.5 MB 28.5 MB/s eta 0:00:01
#    --------------------------------- ------ 42.6/51.5 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.8/51.5 MB 26.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 45.2/51.5 MB 27.3 MB/s eta 0:00:01
#    ------------------------------------ --- 46.4/51.5 MB 27.3 MB/s eta 0:00:01
#    ------------------------------------- -- 47.9/51.5 MB 27.3 MB/s eta 0:00:01
#    -------------------------------------- - 49.1/51.5 MB 28.5 MB/s eta 0:00:01
#    ---------------------------------------  50.5/51.5 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  51.5/51.5 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------  51.5/51.5 MB 29.7 MB/s eta 0:00:01
#    ---------------------------------------- 51.5/51.5 MB 21.8 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.0-cp310-cp310-win_amd64.whl (126 kB)
#    ---------------------------------------- 0.0/126.6 kB ? eta -:--:--
#    ---------------------------------------- 126.6/126.6 kB ? eta 0:00:00
# Installing collected packages: protobuf, ml-dtypes, sounddevice, jaxlib, mediapipe
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.3.0
#     Uninstalling ml-dtypes-0.3.0:
#       Successfully uninstalled ml-dtypes-0.3.0
# Successfully installed jaxlib-0.4.29 mediapipe-0.10.14 ml-dtypes-0.4.0 protobuf-4.25.3 sounddevice-0.4.7
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\jarvis\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\jarvis\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jarvis\anaconda3\envs\detect\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jarvis\anaconda3\envs\detect\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\jarvis\anaconda3\envs\detect\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\jarvis\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\jarvis\anaconda3\envs\detect\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\jarvis\anaconda3\envs\detect\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\jarvis\anaconda3\envs\detect\lib\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\jarvis\appdata\roaming\python\python310\site-packages)
#     WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\jarvis\appdata\roaming\python\python310\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# onnx 1.13.0 requires protobuf<4,>=3.20.2, but you have protobuf 4.25.3 which is incompatible.
# super-gradients 3.1.3 requires numpy<=1.23, but you have numpy 1.23.5 which is incompatible.
# super-gradients 3.1.3 requires onnxruntime==1.13.1, but you have onnxruntime 1.18.0 which is incompatible.
# super-gradients 3.1.3 requires protobuf==3.20.3, but you have protobuf 4.25.3 which is incompatible.
# super-gradients 3.1.3 requires pyparsing==2.4.5, but you have pyparsing 2.4.7 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.12.1 which is incompatible.
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\jarvis\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\jarvis\appdata\roaming\python\python310\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python-headless (c:\users\jarvis\appdata\roaming\python\python310\site-packages)

# %%
import cv2
import mediapipe as mp

# Initialize MediaPipe Hand model
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()
mp_drawing = mp.solutions.drawing_utils

# Open the default camera
cap = cv2.VideoCapture(0)

while cap.isOpened():
    success, image = cap.read()
    if not success:
        print("Ignoring empty camera frame.")
        continue

    # Flip the image horizontally for a later selfie-view display
    # Convert the BGR image to RGB.
    image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
    # Process the image and detect hands
    results = hands.process(image)

    # Convert the image color back so it can be displayed with OpenCV
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # Draw hand annotations on the image.
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    # Display the resulting frame
    cv2.imshow('Hand Tracking', image)

    if cv2.waitKey(5) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 import cv2
# ----> 2 import mediapipe as mp
#       4 # Initialize MediaPipe Hand model
#       5 mp_hands = mp.solutions.hands
#
# File c:\Users\Jarvis\anaconda3\envs\detect\lib\site-packages\mediapipe\__init__.py:17
#      15 from mediapipe.python import *
#      16 import mediapipe.python.solutions as solutions
# ---> 17 import mediapipe.tasks.python as tasks
#      20 del framework
#      21 del gpu
#
# File c:\Users\Jarvis\anaconda3\envs\detect\lib\site-packages\mediapipe\tasks\python\__init__.py:17
#       1 # Copyright 2022 The MediaPipe Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 """MediaPipe Tasks API."""
# ---> 17 from . import audio
#      18 from . import components
#      19 from . import core
#
# File c:\Users\Jarvis\anaconda3\envs\detect\lib\site-packages\mediapipe\tasks\python\audio\__init__.py:21
#      18 import mediapipe.tasks.python.audio.audio_classifier
#      19 import mediapipe.tasks.python.audio.audio_embedder
# ---> 21 AudioClassifier = audio_classifier.AudioClassifier
#      22 AudioClassifierOptions = audio_classifier.AudioClassifierOptions
#      23 AudioClassifierResult = audio_classifier.AudioClassifierResult
#
# NameError: name 'audio_classifier' is not defined

# %%
import cv2
import mediapipe as mp

# Initialize MediaPipe Hand model
mp_hands = mp.solutions.hands
hands = mp_hands.Hands()
mp_drawing = mp.solutions.drawing_utils

# Open the default camera
cap = cv2.VideoCapture(0)

while cap.isOpened():
    success, image = cap.read()
    if not success:
        print("Ignoring empty camera frame.")
        continue

    # Flip the image horizontally for a later selfie-view display
    # Convert the BGR image to RGB.
    image = cv2.cvtColor(cv2.flip(image, 1), cv2.COLOR_BGR2RGB)
    # Process the image and detect hands
    results = hands.process(image)

    # Convert the image color back so it can be displayed with OpenCV
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

    # Draw hand annotations on the image.
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

    # Display the resulting frame
    cv2.imshow('Hand Tracking', image)

    if cv2.waitKey(5) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[4], line 2
#
#       1 import cv2
#
# ----> 2 import mediapipe as mp
#
#       4 # Initialize MediaPipe Hand model
#
#       5 mp_hands = mp.solutions.hands
#
#
#
# File c:\Users\Jarvis\anaconda3\envs\detect\lib\site-packages\mediapipe\__init__.py:17
#
#      15 from mediapipe.python import *
#
#      16 import mediapipe.python.solutions as solutions
#
# ---> 17 import mediapipe.tasks.python as tasks
#
#      20 del framework
#
#      21 del gpu
#
#
#
# File c:\Users\Jarvis\anaconda3\envs\detect\lib\site-packages\mediapipe\tasks\python\__init__.py:17
#
#       1 # Copyright 2022 The MediaPipe Authors.
#
#       2 #
#
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#
#    (...)
#
#      12 # See the License for the specific language governing permissions and
#
#      13 # limitations under the License.
#
#      15 """MediaPipe Tasks API."""
#
# ---> 17 from . import audio
#
#      18 from . import components
#
#      19 from . import core
#
#
#
# File c:\Users\Jarvis\anaconda3\envs\detect\lib\site-packages\mediapipe\tasks\python\audio\__init__.py:21
#
#      18 import mediapipe.tasks.python.audio.audio_classifier
#
#      19 import mediapipe.tasks.python.audio.audio_embedder
#
# ---> 21 AudioClassifier = audio_classifier.AudioClassifier
#
#      22 AudioClassifierOptions = audio_classifier.AudioClassifierOptions
#
#      23 AudioClassifierResult = audio_classifier.AudioClassifierResult
#
#
#
# NameError: name 'audio_classifier' is not defined
